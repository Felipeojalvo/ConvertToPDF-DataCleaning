# %%
import pandas as pd

# %%
df = pd.read_excel("excel_version.xlsx")

# %%
df.isnull()
# Out:
#        ID  Provincia  Departamento  Localidad  Área   Institución  Función  \
# 0   False      False         False      False  False        False    False
# 1   False      False         False      False  False        False    False
# 2   False      False         False      False  False        False    False
# 3    True       True          True       True   True         True     True
# 4   False      False         False      False  False        False    False
# 5   False      False         False      False  False        False    False
# 6   False      False         False      False  False        False    False
# 7   False      False         False      False  False        False    False
# 8   False      False         False      False  False        False    False
# 9   False      False         False      False  False        False    False
# 10   True       True          True       True   True         True     True
# ...

# %%
df.dropna()
# Out:
#       ID Provincia Departamento               Localidad  \
# 0    1.0  Santa Fe   9 De Julio                 Tostado
# 1    2.0  Santa Fe     Belgrano               Armstrong
# 2    3.0  Santa Fe     Belgrano             Las Parejas
# 4    4.0  Santa Fe     Belgrano             Las Parejas
# 5    5.0  Santa Fe     Belgrano               Las Rosas
# 6    6.0  Santa Fe      Caseros                Arequito
# 7    7.0  Santa Fe      Caseros                Arequito
# 8    8.0  Santa Fe      Caseros                Arequito
# 9    9.0  Santa Fe      Caseros                Berabevu
# 13  11.0  Santa Fe      Caseros                 Casilda
# 14  12.0  Santa Fe      Caseros                 Casilda
# 15  13.0  Santa Fe      Caseros                  Chabas
# 16  14.0  Santa Fe      Caseros             Los Molinos
# 17  15.0  Santa Fe  Castellanos             Castellanos
# 19  16.0  Santa Fe  Castellanos                Frontera
# 20  17.0  Santa Fe  Castellanos                 Rafaela
# ...

# %%
df_cleaned = df.dropna()

# %%
excel_clean = "excel_clean.xlsx"

df_cleaned.to_excel(excel_clean, index=False)
